# %%
import numpy as np
import pandas as pd

# %%
# Convertir lista a dataframe

ventas = pd.Series([22, 15, 70])
ventas
# Out:
# 0    22
# 1    15
# 2    70
# dtype: int64

# %%
ventas = pd.Series([22, 15, 70], index = ['Lunes', 'Martes', 'Miercoles'])
ventas
# Out:
# Lunes        22
# Martes       15
# Miercoles    70
# dtype: int64

# %%
ventas["Lunes"]
# Out:
# 22

# %%
ventas.dtype
# Out:
# dtype('int64')

# %%
ventas.index
# Out:
# Index(['Lunes', 'Martes', 'Miercoles'], dtype='object')

# %%
ventas.name = "Ventas por dia"
ventas.index.name = "Dia"
ventas
# Out:
# Dia
# Lunes        22
# Martes       15
# Miercoles    70
# Name: Ventas por dia, dtype: int64

# %%
ventas.shape
# Out:
# (3,)

# %%
# Trabajando con diccionarios
# No tienen indexación
# Poseen una clave única y un valor asociado a la clave

# %%
diccionario = {"Enero": 22, "Febrero":15, "Marzo":70}
type(diccionario)
# Out:
# dict

# %%
ventas1 = pd.Series(diccionario)
ventas1
# Out:
# Enero      22
# Febrero    15
# Marzo      70
# dtype: int64

# %%
hola = pd.Series(diccionario, index = ["Enero", "Febrero", "Marzo", "Abril"])
hola
# Out:
# Enero      22.0
# Febrero    15.0
# Marzo      70.0
# Abril       NaN
# dtype: float64

# %%
medidas = pd.DataFrame({
    "Humedad": [41, 20, 30, 80],
    "Salinidad": [22, 15, 30, 80],
    "Sensorica": ["si", "no", "no", "no"],
    "Acidez": ["alta", "media", "baja", "baja"],
    "PH": [1, 7, 14, 13]
}, index=["La Ureña", "Paso Chico", "La Laguna", "Los Teres"])
medidas
# Out:
#             Humedad  Salinidad Sensorica Acidez  PH
# La Ureña         41         22        si   alta   1
# Paso Chico       20         15        no  media   7
# La Laguna        30         30        no   baja  14
# Los Teres        80         80        no   baja  13

# %%
medidas.Humedad
# Out:
# La Ureña      41
# Paso Chico    20
# La Laguna     30
# Los Teres     80
# Name: Humedad, dtype: int64

# %%
medidas.Acidez
# Out:
# La Ureña       alta
# Paso Chico    media
# La Laguna      baja
# Los Teres      baja
# Name: Acidez, dtype: object

# %%
medidas.columns
# Out:
# Index(['Humedad', 'Salinidad', 'Sensorica', 'Acidez', 'PH'], dtype='object')

# %%
medidas[["Sensorica", "PH"]]
# Out:
#            Sensorica  PH
# La Ureña          si   1
# Paso Chico        no   7
# La Laguna         no  14
# Los Teres         no  13

# %%
medidas.dtypes
# Out:
# Humedad       int64
# Salinidad     int64
# Sensorica    object
# Acidez       object
# PH            int64
# dtype: object

# %%
# Muestra los nombres de filas y columnas
medidas.axes
# Out:
# [Index(['La Ureña', 'Paso Chico', 'La Laguna', 'Los Teres'], dtype='object'),
#  Index(['Humedad', 'Salinidad', 'Sensorica', 'Acidez', 'PH'], dtype='object')]

# %%
medidas.values
# Out:
# array([[41, 22, 'si', 'alta', 1],
#        [20, 15, 'no', 'media', 7],
#        [30, 30, 'no', 'baja', 14],
#        [80, 80, 'no', 'baja', 13]], dtype=object)

# %%
medidas.shape
# Out:
# (4, 5)

# %%
#Ejercicios
elementos = {"numero atomico": [1, 6, 47, 88],
             "masa atomica": [1, 12, 107, 226],
             "familia": ["no metal", "no metal", "metal", "metal"]}
tabla_periodica = pd.DataFrame(elementos, index=["H", "C", "Ag", "Ra"])
tabla_periodica
# Out:
#     numero atomico  masa atomica   familia
# H                1             1  no metal
# C                6            12  no metal
# Ag              47           107     metal
# Ra              88           226     metal

# %%
# Ejercicios

# %%
# Dados los siguientes diccionarios, convertirlos en datagramas y usar todos los métodos aprendidos:

elementos={"número atómico":[1,6,47,88],
"Masa atómica":[1,12,107,226],
"Familia":["No metal","No metal","Metal","Metal"]}

elementos1 = pd.DataFrame(elementos, index=["H","C","Ag","Ra"])
elementos1
# Out:
#     número atómico  Masa atómica   Familia
# H                1             1  No metal
# C                6            12  No metal
# Ag              47           107     Metal
# Ra              88           226     Metal

# %%
# Convertir en dataframe el siguiente conjunto de medidas
medida_2020={"Ag":2,"Au":5,"Cu":3,"Pt":2}
medida_2021={"Ag":4,"Au":3,"Cu":6,"Pt":1}
medida_2022={"Ag":8,"Au":2,"Cu":15,"Pt":0}
medida_2023={"Ag":5,"Au":1,"Cu":0,"Pt":5}
medida_2024={"Ag":7,"Au":0,"Cu":3,"Pt":2}
medida_2025={"Ag":9,"Au":1,"Cu":3,"Pt":5}

medidas = pd.DataFrame([medida_2020, medida_2021, medida_2022, medida_2023, medida_2024, medida_2025], index=[2020, 2021, 2022, 2023, 2024, 2025])
medidas
# Out:
#       Ag  Au  Cu  Pt
# 2020   2   5   3   2
# 2021   4   3   6   1
# 2022   8   2  15   0
# 2023   5   1   0   5
# 2024   7   0   3   2
# 2025   9   1   3   5
